# %%
import pathlib
import textwrap
from PIL import Image
import google.generativeai as genai
from IPython.display import display, Markdown

# %%
def to_markdown(text):
    text = text.replace('•', '  *')
    return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
import os
from dotenv import load_dotenv

load_dotenv()  # loads variables from .env file
api_key = os.getenv("GEMINI_API_KEY")

# %%
img = Image.open(r"sample_img.jpg")   # 👉 Replace with your image filename
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=612x457>

# %%
# Select the Gemini model capable of image understanding
model = genai.GenerativeModel("gemini-2.5-flash")

# Give image and prompt together
response = model.generate_content(
    ["Explain what you see in this image", img],
)

display(to_markdown(response.text))
# Out:
# > In this image, I see a large group of approximately 19 individuals, primarily adults, standing together and looking directly at the camera with warm smiles.
# >
# > Here's a more detailed breakdown:
# >
# > *   **Subjects:** The group is highly diverse in terms of age, gender, and apparent ethnicity. There's a mix of young adults, middle-aged individuals, and seniors, indicating a multi-generational representation. Men and women are present in roughly equal numbers. Visually, the group includes people who appear to be of African, East Asian, South Asian (one man wears a turban), and Caucasian descent, among others.
# > *   **Expressions:** Almost all subjects are smiling broadly or wearing pleasant, approachable expressions, conveying a sense of friendliness, happiness, and openness. Their gazes are directed towards the viewer.
# > *   **Attire:** They are dressed in various styles of casual to smart-casual attire, including t-shirts, sweaters, blouses, button-down shirts, and dresses. There's no uniform, suggesting individual styles within a relaxed setting.
# > *   **Arrangement:** The individuals are arranged in a staggered formation, standing shoulder-to-shoulder in a few rows, with some slightly in front of others, creating a sense of depth and a natural group dynamic.
# > *   **Background:** The background is a plain, solid white wall, which provides a clean and uncluttered backdrop that highlights the people in the foreground.
# > *   **Lighting:** The lighting is bright and even, suggesting a studio setting or professional photography, casting minimal shadows and making all faces clearly visible.
# >
# > Overall, the image projects a positive, inclusive, and welcoming atmosphere, emphasizing diversity and community.
